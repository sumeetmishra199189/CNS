# %% [markdown]
# # Mortality Data Documentation for State Level

# %% [markdown]
# ## Importing Packages

# %%
# Start Python Imports
import math, time, random, datetime

# Data Manipulation
import numpy as np
import pandas as pd

# Visualization 
import matplotlib.pyplot as plt
import missingno
import seaborn as sns
plt.style.use('seaborn-whitegrid')

# %% [markdown]
# ## Reading Data

# %%
mortality_s=pd.read_csv('/Users/sumeetmishra/Desktop/CNS/CDCMortality/Data/NCHS_-_Drug_Poisoning_Mortality_by_State__United_States.csv')
mortality_s.head(15)
# Out:
#       State  Year         Sex Age Group Race and Hispanic Origin  Deaths  \
# 0   Alabama  1999  Both Sexes  All Ages    All Races-All Origins     169
# 1   Alabama  2000  Both Sexes  All Ages    All Races-All Origins     197
# 2   Alabama  2001  Both Sexes  All Ages    All Races-All Origins     216
# 3   Alabama  2002  Both Sexes  All Ages    All Races-All Origins     211
# 4   Alabama  2003  Both Sexes  All Ages    All Races-All Origins     197
# 5   Alabama  2004  Both Sexes  All Ages    All Races-All Origins     283
# 6   Alabama  2005  Both Sexes  All Ages    All Races-All Origins     283
# 7   Alabama  2006  Both Sexes  All Ages    All Races-All Origins     398
# 8   Alabama  2007  Both Sexes  All Ages    All Races-All Origins     511
# 9   Alabama  2008  Both Sexes  All Ages    All Races-All Origins     607
# 10  Alabama  2009  Both Sexes  All Ages    All Races-All Origins     630
# 11  Alabama  2010  Both Sexes  All Ages    All Races-All Origins     547
# ...

# %% [markdown]
# ## Looking at Data types

# %%
mortality_s.dtypes
# Out:
# State                                            object
# Year                                              int64
# Sex                                              object
# Age Group                                        object
# Race and Hispanic Origin                         object
# Deaths                                            int64
# Population                                        int64
# Crude Death Rate                                float64
# Standard Error for Crude Rate                   float64
# Low Confidence Limit for Crude Rate             float64
# Upper Confidence Limit for Crude Rate           float64
# Age-adjusted Rate                               float64
# Standard Error Age-adjusted Rate                float64
# Lower Confidence Limit for Age-adjusted Rate    float64
# Upper Confidence for Age-adjusted Rate          float64
# State Crude Rate in Range                        object
# US Crude Rate                                   float64
# ...

# %% [markdown]
# ## Checking if any missing values

# %%
missingno.matrix(mortality_s, figsize = (30,5))

# %% [markdown]
# ## Checking if any Null values in data

# %%
mortality_s.isnull().sum()
# Out:
# State                                              0
# Year                                               0
# Sex                                                0
# Age Group                                          0
# Race and Hispanic Origin                           0
# Deaths                                             0
# Population                                         0
# Crude Death Rate                                   0
# Standard Error for Crude Rate                      0
# Low Confidence Limit for Crude Rate                0
# Upper Confidence Limit for Crude Rate              0
# Age-adjusted Rate                               1824
# Standard Error Age-adjusted Rate                1824
# Lower Confidence Limit for Age-adjusted Rate    1824
# Upper Confidence for Age-adjusted Rate          1824
# State Crude Rate in Range                       1824
# US Crude Rate                                      0
# US Age-adjusted Rate                               0
# ...

# %% [markdown]
# ## Data Description

# %%
mortality_s.describe()
# Out:
#               Year        Deaths    Population  Crude Death Rate  \
# count  3021.000000   3021.000000  3.021000e+03       3021.000000
# mean   2008.000000   2069.790798  1.671394e+07         11.189616
# std       5.478132   5119.632635  3.470463e+07          9.378648
# min    1999.000000      1.000000  2.381630e+05          0.038900
# 25%    2003.000000    130.000000  2.749686e+06          4.028700
# 50%    2008.000000    508.000000  6.483001e+06          9.359800
# 75%    2013.000000   1613.000000  1.825254e+07         15.323500
# max    2017.000000  70237.000000  3.257192e+08         75.545700
#
#        Standard Error for Crude Rate  Low Confidence Limit for Crude Rate  \
# count                    3021.000000                          3021.000000
# mean                        0.442526                            10.339516
# std                         0.335724                             9.113974
# min                         0.014280                             0.008000
# ...

# %% [markdown]
# ## Let's look into features individually

# %% [markdown]
# ### State

# %%
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(20,10)) 
sns.countplot(y='State', data=mortality_s)

# %% [markdown]
# ### Year

# %%
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(20,10)) 
sns.distplot(mortality_s['Year'])

# %% [markdown]
# ### Sex

# %%
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(20,10)) 
sns.countplot(y='Sex', data=mortality_s)

# %% [markdown]
# ### Age Group

# %%
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(20,10)) 
sns.countplot(y='Age Group', data=mortality_s)

# %% [markdown]
# ### Race and Hispanic Origin

# %%
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(20,10)) 
sns.countplot(y='Race and Hispanic Origin', data=mortality_s)

# %% [markdown]
# ### Deaths

# %%
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(20,10)) 
sns.distplot(mortality_s['Deaths'])

# %% [markdown]
# ### Population

# %%
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(20,10)) 
sns.distplot(mortality_s['Population'])

# %% [markdown]
# ### Crude Death Rate

# %%
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(20,10)) 
sns.distplot(mortality_s['Crude Death Rate'])

# %% [markdown]
# ### Standard Error for Crude Rate

# %%
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(20,10)) 
sns.distplot(mortality_s['Standard Error for Crude Rate'])

# %% [markdown]
# ### Low Confidence Limit for Crude Rate

# %%
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(20,10)) 
sns.distplot(mortality_s['Low Confidence Limit for Crude Rate'])

# %% [markdown]
# ### Upper Confidence Limit for Crude Rate

# %%
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(20,10)) 
sns.distplot(mortality_s['Upper Confidence Limit for Crude Rate'])

# %% [markdown]
# ### US Crude Rate

# %%
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(20,10)) 
sns.distplot(mortality_s['US Crude Rate'])

# %% [markdown]
# ### US Age-adjusted Rate

# %%
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(20,10)) 
sns.distplot(mortality_s['US Age-adjusted Rate'])

# %% [markdown]
# ### Unit

# %%
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(20,10)) 
sns.countplot(y='Unit', data=mortality_s)

# %% [markdown]
# ### State Crude Rate in Range

# %%
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(20,10)) 
sns.countplot(y='State Crude Rate in Range', data=mortality_s)
